# %%
from pathlib import Path
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
gts = Path("/mnt/d/Tommy/sem_adult/everything/gts/SEM_adult_image_export_v_nerve_ring_s209_label.png")
gts_read = cv2.imread(gts, cv2.IMREAD_GRAYSCALE)
plt.imshow(gts_read, cmap='gray')

# %%
np.unique(gts_read, return_index=True)
# Out:
# (array([0, 3], dtype=uint8), array([ 0, 94]))
